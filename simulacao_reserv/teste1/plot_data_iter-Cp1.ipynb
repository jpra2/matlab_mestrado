# %%
(curves1.opts(padding=0.1) + curves2).opts(shared_axes=False)
# Out:
# :Layout
#    .Overlay.I  :Overlay
#       .Curve.Base         :Curve   [x]   (y)
#       .Curve.Base2        :Curve   [x]   (y)
#       .Curve.Base3_c      :Curve   [x]   (y)
#       .Curve.Base3_c2     :Curve   [x]   (y)
#       .Curve.Base3_c3_col :Curve   [x]   (y)
#       .Curve.Base10       :Curve   [x]   (y)
#       .Curve.Base11       :Curve   [x]   (y)
#       .Curve.Base12       :Curve   [x]   (y)
#    .Overlay.II :Overlay
#       .Curve.Base         :Curve   [x]   (y)
#       .Curve.Base2        :Curve   [x]   (y)
#       .Curve.Base3_c      :Curve   [x]   (y)
#       .Curve.Base3_c2     :Curve   [x]   (y)
#       .Curve.Base3_c3_col :Curve   [x]   (y)
#       .Curve.Base10       :Curve   [x]   (y)
#       .Curve.Base11       :Curve   [x]   (y)
#       .Curve.Base12       :Curve   [x]   (y)
